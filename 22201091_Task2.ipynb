# %% [markdown]
# <a href="https://colab.research.google.com/github/KsKarim7/DS-with-Python/blob/main/22201091_Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Solver code

# %%
# You can possibly write helper functions here
def findPair(arr):
    # You only need to write code here
    arr_set = set()
    for i in range(len(arr)):
        com = 100 - arr[i]
        if com in arr_set:
            return (i, arr.index(com))
        arr_set.add(arr[i])
    return None
    # return (0, 0)

# %% [markdown]
# # Driver Code

# %%
# Variables: itr, jtr, tSize, tFlag, tScore, sScore, rValue, inpArr
import sys, time, signal, random
sys.setrecursionlimit(9999999)
tScore = 5
sScore = 0
rValue = (0, 0)
tSize = [10, 100, 1000, 10000, 100000]
def handle_timeout(signum, frame):
    raise TimeoutError
for itr in range(tScore):
    signal.signal(signal.SIGALRM, handle_timeout)
    signal.alarm(2)
    tFlag = True
    inpArr = [0.0 for jtr in range(tSize[itr])]
    for jtr in range(tSize[itr]):
        inpArr[jtr] = random.uniform(1, 99)
    inpArr[-1] = 100 - inpArr[0]
    random.shuffle(inpArr)
    try:
        rValue = findPair(inpArr)
    except TimeoutError:
        print('Your function took more than 2 seconds to run on the test number', itr + 1)
        tFlag = False
    finally:
        signal.alarm(0)
    if tFlag == True:
        if inpArr[rValue[0]] + inpArr[rValue[1]] != 100:
            print('Your function returned wrong answer on the test number', itr + 1)
        else:
            print('Your function passed the test number', itr + 1)
            sScore += 1
print('Your score is', sScore, 'out of', tScore)
